# %% [markdown]
# ## Setup

# %%
# !nvidia-smi
# Out:
# Wed Dec  3 05:03:28 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A40                     On  |   00000000:C1:00.0 Off |                    0 |
# |  0%   30C    P8             21W /  300W |       0MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pace-quota
# Out:
# Gathering storage and job accounting information for user: wchia7
#
#   ** Please note that the information and display format of this tool **
#   ** is subject to change and should *not* be used for scripting.    **
#
#
# ================================================================================================================
#                                           Welcome to the ICE Cluster!
# ================================================================================================================
#  * Your Name (as PACE knows it)          :   Wen Han Chia
#  * UserID                                :   3370265
#  * Username                              :   wchia7
#  * Your Email (for PACE contact)         :
#
# ================================================================================================================
#                                                   ICE Storage
# ================================================================================================================
# Filesystem                                             Usage (GB)    Limit
# Home:/home/hice1/wchia7                                      13.7     30.0  45.6%
# Scratch:/storage/ice1/6/5/wchia7                            223.1    300.0  74.4%

# %% [markdown]
# Install YOLO package

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (8.3.223)
# Requirement already satisfied: numpy>=1.23.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /home/hice1/wchia7/.local/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (1.34.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/hice1/wchia7/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /home/hice1/wchia7/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /home/hice1/wchia7/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from triton==3.4.0->torch>=1.8.0->ultralytics) (75.8.0)
# Requirement already satisfied: polars-runtime-32==1.34.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from polars->ultralytics) (1.34.0)
# Requirement already satisfied: six>=1.5 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hice1/wchia7/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /storage/ice1/6/5/wchia7/conda_venvs/lizard_class/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
from ultralytics import YOLO 
import os
from IPython.display import display, Image 
from IPython import display 
display.clear_output()

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.3.223

# %%
from pipeline_evaluation import evaluate_performance

# %% [markdown]
# ## Evaluate Model's Performance

# %% [markdown]
# ## Run evaluation script

# %% [markdown]
# ### Evaluate for mAP

# %%
evaluate_performance(yolo_model_file_path="./runs/detect/train22_yolov12x_dataset_v4/weights/best.pt",
    swin_model_file_path=None, det_conf_thresh=0.001, nms_iou_thresh=0.7, eval_iou_thresh = 0.5, top_k=5)
# Out:
# --- EVALUATION PIPELINE ---
# YOLO Model Config: NMS_IOU_THRESHOLD: 0.7
#  CONF_THRESH: 0.001
#  MAX_DETECTION: 5
#
# EVAL Config: EVAL_IOU_THRESHOLD: 0.5
#
# --- LOADING MODELS ---
# YOLO_MODEL_FILE_PATH: ./runs/detect/train22_yolov12x_dataset_v4/weights/best.pt
#
# --- COMPLETED LOADING MODELS ---
# --- Saving results and debug images to inference/run_20251205_110700 ---
#
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9891309.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9891309.txt
#
# Label File content (GT): [1.0, 0.25234375, 0.42734375, 0.50390625, 0.25]
# GT Box (yolo to xyxy): [0, 194, 323, 354]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 brown_anole, 4 knight_anoles, 31.2ms
# Speed: 2.7ms preprocess, 31.2ms inference, 15.8ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.2191e+00, 1.9707e+02, 3.2245e+02, 3.4879e+02, 7.9054e-01, 1.0000e+00],
#         [6.6040e-01, 1.9808e+02, 3.2259e+02, 4.8935e+02, 2.9687e-03, 4.0000e+00],
#         [2.2762e+02, 6.0806e+02, 3.7388e+02, 6.3959e+02, 2.3515e-03, 4.0000e+00],
#         [1.8624e+02, 6.0428e+02, 4.0789e+02, 6.3984e+02, 1.5472e-03, 4.0000e+00],
#         [8.2170e+01, 6.0370e+02, 4.3183e+02, 6.3977e+02, 1.1503e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [2.219146728515625, 197.07150268554688, 322.4494934082031, 348.7940368652344, 0.7905368804931641, 1.0]
# Prediction bbox: 2 197 322 349, Conf: 0.791, Pred_label: brown
# Individual Detection result: [0.660400390625, 198.07550048828125, 322.5902099609375, 489.3536376953125, 0.002968650544062257, 4.0]
# Prediction bbox: 1 198 323 489, Conf: 0.003, Pred_label: knight
# Individual Detection result: [227.61724853515625, 608.0587768554688, 373.8792724609375, 639.5946655273438, 0.0023515073116868734, 4.0]
# Prediction bbox: 228 608 374 639, Conf: 0.002, Pred_label: knight
# Individual Detection result: [186.2418212890625, 604.280029296875, 407.88525390625, 639.84326171875, 0.0015472288941964507, 4.0]
# Prediction bbox: 186 604 408 639, Conf: 0.002, Pred_label: knight
# Individual Detection result: [82.1695556640625, 603.7010498046875, 431.83392333984375, 639.7652587890625, 0.0011502956040203571, 4.0]
# Prediction bbox: 82 604 432 639, Conf: 0.001, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/116461_9891309_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.9411764705882353
# No best match found for Pred: knight
# No best match found for Pred: knight
# No best match found for Pred: knight
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9891309_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9891309_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9891309_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9891309_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_893241.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_893241.txt
#
# Label File content (GT): [3.0, 0.48515625, 0.64296875, 0.30390625, 0.70234375]
# GT Box (yolo to xyxy): [213, 187, 408, 636]
#
# --- Pipeline inference ---
#
# 0: 640x640 2 green_anoles, 1 knight_anole, 31.2ms
# Speed: 2.3ms preprocess, 31.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.9412e+02, 1.8676e+02, 4.0830e+02, 6.3970e+02, 8.3328e-01, 3.0000e+00],
#         [4.9362e+01, 1.8761e+02, 4.1018e+02, 6.3850e+02, 1.8255e-02, 4.0000e+00],
#         [2.1880e+02, 1.8704e+02, 4.0856e+02, 5.2710e+02, 3.8804e-03, 3.0000e+00]], device='cuda:0')
# Individual Detection result: [194.12335205078125, 186.75897216796875, 408.29864501953125, 639.701416015625, 0.8332821130752563, 3.0]
# Prediction bbox: 194 187 408 639, Conf: 0.833, Pred_label: green
# Individual Detection result: [49.36151123046875, 187.61415100097656, 410.1790771484375, 638.4981689453125, 0.018255410715937614, 4.0]
# Prediction bbox: 49 188 410 638, Conf: 0.018, Pred_label: knight
# Individual Detection result: [218.8032684326172, 187.037841796875, 408.55804443359375, 527.10205078125, 0.0038803936913609505, 3.0]
# Prediction bbox: 219 187 409 527, Conf: 0.004, Pred_label: green
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36514_893241_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.9051670664130345
# No best match found for Pred: knight
# No best match found for Pred: green
# Annotated image saved to: inference/run_20251205_110700/false_positives/36514_893241_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36514_893241_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_82799705.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_82799705.txt
#
# Label File content (GT): [4.0, 0.46796875, 0.44921875, 0.20234375, 0.28984375]
# GT Box (yolo to xyxy): [235, 195, 364, 380]
#
# --- Pipeline inference ---
#
# 0: 640x640 5 knight_anoles, 31.1ms
# Speed: 1.5ms preprocess, 31.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.2689e+02, 1.8909e+02, 3.7848e+02, 3.7013e+02, 4.5223e-01, 4.0000e+00],
#         [2.2795e+02, 1.9139e+02, 4.5990e+02, 3.7511e+02, 4.4594e-02, 4.0000e+00],
#         [2.2674e+02, 1.9039e+02, 4.1162e+02, 4.9535e+02, 3.3342e-02, 4.0000e+00],
#         [2.2400e+02, 1.9050e+02, 5.5067e+02, 3.8074e+02, 1.2240e-02, 4.0000e+00],
#         [2.2735e+02, 1.8888e+02, 3.8724e+02, 6.0602e+02, 1.0902e-02, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [226.89138793945312, 189.0914306640625, 378.4768371582031, 370.12603759765625, 0.452229380607605, 4.0]
# Prediction bbox: 227 189 378 370, Conf: 0.452, Pred_label: knight
# Individual Detection result: [227.9527587890625, 191.38893127441406, 459.8958740234375, 375.107421875, 0.04459378868341446, 4.0]
# Prediction bbox: 228 191 460 375, Conf: 0.045, Pred_label: knight
# Individual Detection result: [226.73947143554688, 190.3888397216797, 411.6241149902344, 495.35455322265625, 0.03334220126271248, 4.0]
# Prediction bbox: 227 190 412 495, Conf: 0.033, Pred_label: knight
# Individual Detection result: [223.998779296875, 190.5003204345703, 550.6748657226562, 380.73773193359375, 0.012240307405591011, 4.0]
# Prediction bbox: 224 191 551 381, Conf: 0.012, Pred_label: knight
# Individual Detection result: [227.35301208496094, 188.8812713623047, 387.2353515625, 606.0186157226562, 0.01090202946215868, 4.0]
# Prediction bbox: 227 189 387 606, Conf: 0.011, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_82799705_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.7887565074595577
# No best match found for Pred: knight
# No best match found for Pred: knight
# No best match found for Pred: knight
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_82799705_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_82799705_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_82799705_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_82799705_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_96732137.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_96732137.txt
#
# Label File content (GT): [4.0, 0.51015625, 0.31328125, 0.66015625, 0.6265625]
# GT Box (yolo to xyxy): [115, 0, 538, 401]
#
# --- Pipeline inference ---
#
# 0: 640x640 3 knight_anoles, 31.1ms
# Speed: 1.4ms preprocess, 31.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.2160e+02, 0.0000e+00, 5.4927e+02, 6.3398e+02, 8.0799e-01, 4.0000e+00],
#         [1.8171e+02, 0.0000e+00, 6.4000e+02, 5.0442e+02, 2.6741e-03, 4.0000e+00],
#         [1.9741e+02, 2.7307e+02, 4.4706e+02, 4.6133e+02, 2.0420e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [121.60479736328125, 0.0, 549.2677001953125, 633.9813842773438, 0.8079913854598999, 4.0]
# Prediction bbox: 122 0 549 634, Conf: 0.808, Pred_label: knight
# Individual Detection result: [181.71363830566406, 0.0, 640.0, 504.4167785644531, 0.002674076473340392, 4.0]
# Prediction bbox: 182 0 639 504, Conf: 0.003, Pred_label: knight
# Individual Detection result: [197.41131591796875, 273.06640625, 447.05755615234375, 461.33099365234375, 0.0020419852808117867, 4.0]
# Prediction bbox: 197 273 447 461, Conf: 0.002, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_96732137_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.6098747829266064
# No best match found for Pred: knight
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_96732137_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_96732137_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_91198274.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_91198274.txt
#
# Label File content (GT): [4.0, 0.63203125, 0.5671875, 0.73046875, 0.4578125]
# GT Box (yolo to xyxy): [171, 216, 638, 510]
#
# --- Pipeline inference ---
#
# 0: 640x640 5 knight_anoles, 28.7ms
# Speed: 1.4ms preprocess, 28.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.7253e+02, 2.1833e+02, 4.3839e+02, 3.8307e+02, 5.0052e-01, 4.0000e+00],
#         [1.7199e+02, 2.1836e+02, 6.3637e+02, 4.6818e+02, 1.1199e-01, 4.0000e+00],
#         [1.7194e+02, 2.1873e+02, 5.3771e+02, 4.0712e+02, 1.0615e-01, 4.0000e+00],
#         [1.7228e+02, 2.1821e+02, 6.3446e+02, 5.9504e+02, 4.0915e-02, 4.0000e+00],
#         [1.7224e+02, 2.1970e+02, 4.6170e+02, 4.4331e+02, 4.0568e-02, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [172.5308837890625, 218.33206176757812, 438.39190673828125, 383.0671691894531, 0.5005197525024414, 4.0]
# Prediction bbox: 173 218 438 383, Conf: 0.501, Pred_label: knight
# Individual Detection result: [171.985107421875, 218.36492919921875, 636.3709106445312, 468.18377685546875, 0.11198581010103226, 4.0]
# Prediction bbox: 172 218 636 468, Conf: 0.112, Pred_label: knight
# Individual Detection result: [171.94024658203125, 218.7325439453125, 537.7070922851562, 407.12188720703125, 0.10614587366580963, 4.0]
# Prediction bbox: 172 219 538 407, Conf: 0.106, Pred_label: knight
# Individual Detection result: [172.27728271484375, 218.20880126953125, 634.455810546875, 595.0415649414062, 0.04091493785381317, 4.0]
# Prediction bbox: 172 218 634 595, Conf: 0.041, Pred_label: knight
# Individual Detection result: [172.24136352539062, 219.70204162597656, 461.7030334472656, 443.3148193359375, 0.04056784510612488, 4.0]
# Prediction bbox: 172 220 462 443, Conf: 0.041, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_91198274_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: knight
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.8448775655872628
# No best match found for Pred: knight
# No best match found for Pred: knight
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_91198274_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_91198274_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_91198274_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_91198274_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_95815604.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_95815604.txt
#
# Label File content (GT): [2.0, 0.50390625, 0.47109375, 0.93671875, 0.9421875]
# GT Box (yolo to xyxy): [23, 0, 622, 603]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[ 21.6434,   0.0000, 628.1880, 606.9562,   0.8886,   2.0000]], device='cuda:0')
# Individual Detection result: [21.64337158203125, 0.0, 628.18798828125, 606.9561767578125, 0.8885648250579834, 2.0]
# Prediction bbox: 22 0 628 607, Conf: 0.889, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_95815604_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.981935178690851
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_84714837.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_84714837.txt
#
# Label File content (GT): [4.0, 0.43046875, 0.50625, 0.8609375, 0.25]
# GT Box (yolo to xyxy): [0, 244, 551, 404]
#
# --- Pipeline inference ---
#
# 0: 640x640 2 knight_anoles, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[0.0000e+00, 2.3786e+02, 5.5257e+02, 4.0332e+02, 9.1904e-01, 4.0000e+00],
#         [1.8408e+00, 2.3402e+02, 5.4471e+02, 5.9473e+02, 1.0313e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [0.0, 237.8633575439453, 552.5665283203125, 403.32159423828125, 0.9190400838851929, 4.0]
# Prediction bbox: 0 238 553 403, Conf: 0.919, Pred_label: knight
# Individual Detection result: [1.84075927734375, 234.01856994628906, 544.7147216796875, 594.7315673828125, 0.0010312844533473253, 4.0]
# Prediction bbox: 2 234 545 595, Conf: 0.001, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_84714837_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.9543879907621247
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_84714837_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9891671.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9891671.txt
#
# Label File content (GT): [1.0, 0.4109375, 0.5078125, 0.309375, 0.05625]
# GT Box (yolo to xyxy): [164, 307, 362, 343]
#
# --- Pipeline inference ---
#
# 0: 640x640 3 brown_anoles, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.6666e+02, 3.0682e+02, 3.6136e+02, 3.4654e+02, 8.6388e-01, 1.0000e+00],
#         [1.6773e+02, 3.0294e+02, 6.3864e+02, 3.4784e+02, 1.5830e-01, 1.0000e+00],
#         [1.6459e+02, 3.0758e+02, 5.4300e+02, 3.4573e+02, 8.2370e-02, 1.0000e+00]], device='cuda:0')
# Individual Detection result: [166.6586151123047, 306.81951904296875, 361.36260986328125, 346.53582763671875, 0.863875687122345, 1.0]
# Prediction bbox: 167 307 361 347, Conf: 0.864, Pred_label: brown
# Individual Detection result: [167.729736328125, 302.94415283203125, 638.6424560546875, 347.83551025390625, 0.1582983285188675, 1.0]
# Prediction bbox: 168 303 639 348, Conf: 0.158, Pred_label: brown
# Individual Detection result: [164.59185791015625, 307.57562255859375, 542.998779296875, 345.7342529296875, 0.08237028867006302, 1.0]
# Prediction bbox: 165 308 543 346, Conf: 0.082, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110700/annotated_images/116461_9891671_annotated.jpg
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.8836032388663968
# No best match found for Pred: brown
# No best match found for Pred: brown
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9891671_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9891671_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_92824180.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_92824180.txt
#
# Label File content (GT): [4.0, 0.58515625, 0.475, 0.12265625, 0.246875]
# GT Box (yolo to xyxy): [335, 225, 414, 383]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[329.2411, 230.5374, 413.1867, 383.9005,   0.9154,   4.0000]], device='cuda:0')
# Individual Detection result: [329.2411193847656, 230.537353515625, 413.1867370605469, 383.9005126953125, 0.9153674840927124, 4.0]
# Prediction bbox: 329 231 413 384, Conf: 0.915, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_92824180_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.8796557352722956
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_85657940.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_85657940.txt
#
# Label File content (GT): [4.0, 0.501623, 0.55113, 0.387246, 0.897739]
# GT Box (yolo to xyxy): [116, 51, 261, 499]
#
# --- Pipeline inference ---
#
# 0: 640x480 1 knight_anole, 68.1ms
# Speed: 1.9ms preprocess, 68.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Raw Detection result: tensor([[118.9473,  55.2375, 275.1701, 500.0000,   0.9186,   4.0000]], device='cuda:0')
# Individual Detection result: [118.94731140136719, 55.23753356933594, 275.1701354980469, 500.0, 0.9186434149742126, 4.0]
# Prediction bbox: 119 55 275 499, Conf: 0.919, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_85657940_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.8858042036641565
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9811279.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9811279.txt
#
# Label File content (GT): [2.0, 0.4890625, 0.5046875, 0.31875, 0.821875]
# GT Box (yolo to xyxy): [211, 60, 415, 586]
#
# --- Pipeline inference ---
#
# 0: 640x640 2 crested_anoles, 29.3ms
# Speed: 1.5ms preprocess, 29.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.0795e+02, 6.1729e+01, 4.1765e+02, 5.8514e+02, 8.9555e-01, 2.0000e+00],
#         [2.7063e+02, 6.0721e+01, 4.1792e+02, 3.6739e+02, 9.3493e-03, 2.0000e+00]], device='cuda:0')
# Individual Detection result: [207.94818115234375, 61.72906494140625, 417.64862060546875, 585.1415405273438, 0.8955536484718323, 2.0]
# Prediction bbox: 208 62 418 585, Conf: 0.896, Pred_label: crested
# Individual Detection result: [270.62646484375, 60.721343994140625, 417.9168701171875, 367.3930969238281, 0.009349320083856583, 2.0]
# Prediction bbox: 271 61 418 367, Conf: 0.009, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_9811279_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9660455261585267
# No best match found for Pred: crested
# Annotated image saved to: inference/run_20251205_110700/false_positives/36488_9811279_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_70774235.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_70774235.txt
#
# Label File content (GT): [0.0, 0.6265625, 0.496875, 0.22421875, 0.49765625]
# GT Box (yolo to xyxy): [329, 159, 473, 477]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 bark_anole, 28.6ms
# Speed: 1.7ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[329.5589, 157.1558, 478.0306, 477.8622,   0.9361,   0.0000]], device='cuda:0')
# Individual Detection result: [329.55889892578125, 157.15576171875, 478.03057861328125, 477.86224365234375, 0.93613201379776, 0.0]
# Prediction bbox: 330 157 478 478, Conf: 0.936, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36455_70774235_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: bark -> GT: bark IOU: 0.9508217287667796
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9925551.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9925551.txt
#
# Label File content (GT): [1.0, 0.4953125, 0.29375, 0.30078125, 0.0875]
# GT Box (yolo to xyxy): [221, 160, 413, 216]
#
# --- Pipeline inference ---
#
# 0: 640x640 5 knight_anoles, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.2035e+02, 1.5848e+02, 4.1544e+02, 2.1599e+02, 8.8529e-01, 4.0000e+00],
#         [3.6842e+02, 1.4472e+02, 6.4000e+02, 5.0349e+02, 3.1880e-03, 4.0000e+00],
#         [3.7104e+02, 3.3918e+02, 6.3987e+02, 4.8994e+02, 2.8027e-03, 4.0000e+00],
#         [3.6964e+02, 2.2684e+02, 5.1035e+02, 4.7896e+02, 1.0488e-03, 4.0000e+00],
#         [2.4054e+02, 1.5592e+02, 6.4000e+02, 5.0500e+02, 1.0014e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [220.35076904296875, 158.4832763671875, 415.4407958984375, 215.99365234375, 0.8852859735488892, 4.0]
# Prediction bbox: 220 158 415 216, Conf: 0.885, Pred_label: knight
# Individual Detection result: [368.41546630859375, 144.7201690673828, 640.0, 503.49005126953125, 0.0031880445312708616, 4.0]
# Prediction bbox: 368 145 639 503, Conf: 0.003, Pred_label: knight
# Individual Detection result: [371.03619384765625, 339.1829833984375, 639.8663330078125, 489.935302734375, 0.0028026869986206293, 4.0]
# Prediction bbox: 371 339 639 490, Conf: 0.003, Pred_label: knight
# Individual Detection result: [369.6440124511719, 226.83763122558594, 510.3476867675781, 478.9635009765625, 0.0010488313855603337, 4.0]
# Prediction bbox: 370 227 510 479, Conf: 0.001, Pred_label: knight
# Individual Detection result: [240.53741455078125, 155.9248809814453, 640.0, 505.00482177734375, 0.0010014432482421398, 4.0]
# Prediction bbox: 241 156 639 505, Conf: 0.001, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/116461_9925551_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: brown IOU: 0.9506631299734748
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110700/mis_classification/116461_9925551_annotated.jpg
# No best match found for Pred: knight
# No best match found for Pred: knight
# No best match found for Pred: knight
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9925551_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9925551_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9925551_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9925551_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_94470018.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_94470018.txt
#
# Label File content (GT): [4.0, 0.3453125, 0.6546875, 0.690625, 0.6859375]
# GT Box (yolo to xyxy): [0, 200, 442, 638]
#
# --- Pipeline inference ---
# 0: 640x640 2 knight_anoles, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[7.4277e-01, 1.9734e+02, 4.4105e+02, 6.3921e+02, 9.6772e-01, 4.0000e+00],
#         [1.6893e+02, 3.0439e+02, 3.7408e+02, 5.4830e+02, 5.0551e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [0.742767333984375, 197.3431396484375, 441.0475158691406, 639.2056884765625, 0.9677172899246216, 4.0]
# Prediction bbox: 1 197 441 639, Conf: 0.968, Pred_label: knight
# Individual Detection result: [168.93222045898438, 304.39154052734375, 374.0798645019531, 548.296142578125, 0.005055105779320002, 4.0]
# Prediction bbox: 169 304 374 548, Conf: 0.005, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_94470018_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.9865066852310653
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_94470018_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_613168.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_613168.txt
#
# Label File content (GT): [3.0, 0.490625, 0.5359375, 0.55234375, 0.92421875]
# GT Box (yolo to xyxy): [137, 47, 491, 639]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[141.3590,  47.4975, 501.9824, 639.9526,   0.9395,   3.0000]], device='cuda:0')
# Individual Detection result: [141.3590087890625, 47.49749755859375, 501.982421875, 639.9525756835938, 0.9394688010215759, 3.0]
# Prediction bbox: 141 47 502 639, Conf: 0.939, Pred_label: green
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36514_613168_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.958904109589041
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_81505029.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_81505029.txt
#
# Label File content (GT): [4.0, 0.47421875, 0.54375, 0.94765625, 0.85390625]
# GT Box (yolo to xyxy): [0, 75, 607, 621]
#
# --- Pipeline inference ---
#
# 0: 640x640 4 knight_anoles, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.7418e+02, 7.7469e+01, 6.0842e+02, 5.4317e+02, 9.2512e-01, 4.0000e+00],
#         [1.1209e+00, 7.3427e+01, 6.0996e+02, 6.0950e+02, 5.3825e-01, 4.0000e+00],
#         [5.1782e-01, 2.8127e+02, 6.1155e+02, 5.9851e+02, 8.9194e-03, 4.0000e+00],
#         [6.9089e-01, 3.2744e+01, 2.9928e+02, 6.0703e+02, 1.6924e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [274.18267822265625, 77.46923828125, 608.4205932617188, 543.166259765625, 0.9251232743263245, 4.0]
# Prediction bbox: 274 77 608 543, Conf: 0.925, Pred_label: knight
# Individual Detection result: [1.12091064453125, 73.42718505859375, 609.9553833007812, 609.5031127929688, 0.5382500886917114, 4.0]
# Prediction bbox: 1 73 610 610, Conf: 0.538, Pred_label: knight
# Individual Detection result: [0.517822265625, 281.2703857421875, 611.5501708984375, 598.5142822265625, 0.00891942624002695, 4.0]
# Prediction bbox: 1 281 612 599, Conf: 0.009, Pred_label: knight
# Individual Detection result: [0.690887451171875, 32.74371337890625, 299.27783203125, 607.0316772460938, 0.0016923750517889857, 4.0]
# Prediction bbox: 1 33 299 607, Conf: 0.002, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_81505029_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: knight
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.9699771125970471
# No best match found for Pred: knight
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_81505029_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_81505029_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_81505029_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_97023199.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_97023199.txt
#
# Label File content (GT): [4.0, 0.63671875, 0.57890625, 0.71171875, 0.6296875]
# GT Box (yolo to xyxy): [180, 169, 635, 572]
#
# --- Pipeline inference ---
#
# 0: 640x640 2 knight_anoles, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.7924e+02, 1.6601e+02, 6.3989e+02, 5.7474e+02, 9.6012e-01, 4.0000e+00],
#         [1.8035e+02, 1.6671e+02, 5.2886e+02, 3.7418e+02, 5.0942e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [179.24464416503906, 166.0054931640625, 639.888671875, 574.7374267578125, 0.9601156115531921, 4.0]
# Prediction bbox: 179 166 639 575, Conf: 0.960, Pred_label: knight
# Individual Detection result: [180.35150146484375, 166.71136474609375, 528.8638916015625, 374.17742919921875, 0.0050941696390509605, 4.0]
# Prediction bbox: 180 167 529 374, Conf: 0.005, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_97023199_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.9746199638567025
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_97023199_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_85134369.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_85134369.txt
#
# Label File content (GT): [2.0, 0.4828125, 0.521875, 0.965625, 0.58828125]
# GT Box (yolo to xyxy): [0, 146, 618, 522]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[  0.8512, 144.5353, 620.9907, 522.7133,   0.8808,   2.0000]], device='cuda:0')
# Individual Detection result: [0.8511962890625, 144.5352783203125, 620.99072265625, 522.7132568359375, 0.8808454275131226, 2.0]
# Prediction bbox: 1 145 621 523, Conf: 0.881, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_85134369_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9883102719651012
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_76820250.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_76820250.txt
#
# Label File content (GT): [2.0, 0.4640625, 0.565625, 0.3203125, 0.8109375]
# GT Box (yolo to xyxy): [194, 102, 400, 622]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[196.1821, 104.3205, 399.8879, 624.4648,   0.8524,   2.0000]], device='cuda:0')
# Individual Detection result: [196.18211364746094, 104.32049560546875, 399.887939453125, 624.46484375, 0.852373480796814, 2.0]
# Prediction bbox: 196 104 400 624, Conf: 0.852, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_76820250_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9827393795104531
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9938238.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9938238.txt
#
# Label File content (GT): [2.0, 0.385232, 0.181013, 0.455696, 0.210127]
# GT Box (yolo to xyxy): [59, 38, 230, 143]
#
# --- Pipeline inference ---
# 0: 640x480 1 brown_anole, 1 crested_anole, 1 knight_anole, 24.0ms
# Speed: 1.8ms preprocess, 24.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Raw Detection result: tensor([[3.5797e+01, 4.9805e+01, 2.3462e+02, 1.4399e+02, 8.1729e-01, 2.0000e+00],
#         [8.0252e-02, 1.9950e+02, 3.7019e+02, 4.9949e+02, 7.2579e-03, 1.0000e+00],
#         [7.9007e-01, 2.8970e+02, 3.6313e+02, 5.0000e+02, 1.1988e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [35.79677963256836, 49.80522537231445, 234.6222381591797, 143.9908447265625, 0.8172851204872131, 2.0]
# Prediction bbox: 36 50 235 144, Conf: 0.817, Pred_label: crested
# Individual Detection result: [0.08025169372558594, 199.5041046142578, 370.1922302246094, 499.4880676269531, 0.007257911376655102, 1.0]
# Prediction bbox: 0 200 370 499, Conf: 0.007, Pred_label: brown
# Individual Detection result: [0.7900714874267578, 289.70489501953125, 363.1281433105469, 500.0, 0.0011987951584160328, 4.0]
# Prediction bbox: 1 290 363 499, Conf: 0.001, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_9938238_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.7661142691974179
# No best match found for Pred: brown
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36488_9938238_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36488_9938238_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_9538375.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_9538375.txt
#
# Label File content (GT): [4.0, 0.5640625, 0.46875, 0.86640625, 0.33828125]
# GT Box (yolo to xyxy): [84, 192, 638, 408]
#
# --- Pipeline inference ---
#
# 0: 640x640 3 bark_anoles, 1 crested_anole, 1 knight_anole, 29.3ms
# Speed: 1.4ms preprocess, 29.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[3.0355e+02, 2.3391e+02, 4.3226e+02, 3.0874e+02, 4.2218e-01, 0.0000e+00],
#         [3.0440e+02, 2.3419e+02, 3.8727e+02, 3.0754e+02, 2.2489e-01, 0.0000e+00],
#         [3.0403e+02, 2.3337e+02, 4.3548e+02, 2.8523e+02, 1.2477e-01, 0.0000e+00],
#         [1.7708e+02, 4.7740e-01, 3.7327e+02, 1.0255e+02, 1.6828e-02, 2.0000e+00],
#         [3.4808e+02, 3.0426e+02, 6.3647e+02, 4.0699e+02, 7.3907e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [303.5458679199219, 233.906982421875, 432.2601623535156, 308.73565673828125, 0.4221831262111664, 0.0]
# Prediction bbox: 304 234 432 309, Conf: 0.422, Pred_label: bark
# Individual Detection result: [304.39825439453125, 234.18936157226562, 387.2747802734375, 307.5415954589844, 0.22489170730113983, 0.0]
# Prediction bbox: 304 234 387 308, Conf: 0.225, Pred_label: bark
# Individual Detection result: [304.026123046875, 233.36746215820312, 435.4765625, 285.2265319824219, 0.12476993352174759, 0.0]
# Prediction bbox: 304 233 435 285, Conf: 0.125, Pred_label: bark
# Individual Detection result: [177.08419799804688, 0.4774017333984375, 373.2651672363281, 102.55239868164062, 0.01682761311531067, 2.0]
# Prediction bbox: 177 0 373 103, Conf: 0.017, Pred_label: crested
# Individual Detection result: [348.07647705078125, 304.2557373046875, 636.4711303710938, 406.989501953125, 0.007390690967440605, 4.0]
# Prediction bbox: 348 304 636 407, Conf: 0.007, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_9538375_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: bark
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: bark
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: bark
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: crested
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/missed_detections/36391_9538375_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_9538375_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_9538375_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_9538375_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_9538375_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_9538375_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_577947.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_577947.txt
#
# Label File content (GT): [3.0, 0.4921875, 0.6640625, 0.23203125, 0.65625]
# GT Box (yolo to xyxy): [241, 215, 389, 635]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.5ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[237.9362, 216.0599, 391.4650, 639.7961,   0.9052,   3.0000]], device='cuda:0')
# Individual Detection result: [237.9361572265625, 216.05987548828125, 391.46502685546875, 639.7960815429688, 0.9052202105522156, 3.0]
# Prediction bbox: 238 216 391 639, Conf: 0.905, Pred_label: green
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36514_577947_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.9559868654323462
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_850152.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_850152.txt
#
# Label File content (GT): [3.0, 0.446875, 0.4734375, 0.23125, 0.575]
# GT Box (yolo to xyxy): [212, 119, 360, 487]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[249.6374, 119.4442, 359.0204, 482.8085,   0.9395,   3.0000]], device='cuda:0')
# Individual Detection result: [249.63742065429688, 119.4442138671875, 359.0204162597656, 482.8084716796875, 0.9394591450691223, 3.0]
# Prediction bbox: 250 119 359 483, Conf: 0.939, Pred_label: green
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36514_850152_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.7284811985898942
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_75082114.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_75082114.txt
#
# Label File content (GT): [2.0, 0.5375, 0.47109375, 0.64296875, 0.59765625]
# GT Box (yolo to xyxy): [138, 110, 550, 493]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[138.5648, 109.9212, 553.0391, 495.3536,   0.9431,   2.0000]], device='cuda:0')
# Individual Detection result: [138.56475830078125, 109.92121887207031, 553.0390625, 495.35357666015625, 0.9431416392326355, 2.0]
# Prediction bbox: 139 110 553 495, Conf: 0.943, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_75082114_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9852290437057576
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_613970.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_613970.txt
#
# Label File content (GT): [3.0, 0.559375, 0.52421875, 0.4296875, 0.76015625]
# GT Box (yolo to xyxy): [220, 92, 496, 579]
#
# --- Pipeline inference ---
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[218.4639,  92.2137, 539.7923, 638.8016,   0.9451,   3.0000]], device='cuda:0')
# Individual Detection result: [218.4638671875, 92.21368408203125, 539.7922973632812, 638.8015747070312, 0.9450724720954895, 3.0]
# Prediction bbox: 218 92 540 639, Conf: 0.945, Pred_label: green
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36514_613970_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.7631235309480282
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_73530109.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_73530109.txt
#
# Label File content (GT): [0.0, 0.5328125, 0.39140625, 0.27578125, 0.7828125]
# GT Box (yolo to xyxy): [253, 0, 429, 501]
#
# --- Pipeline inference ---
#
# 0: 640x640 3 bark_anoles, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.5526e+02, 9.4745e-01, 4.4159e+02, 5.0367e+02, 6.8195e-01, 0.0000e+00],
#         [2.5536e+02, 3.0424e+00, 6.3749e+02, 5.0638e+02, 9.8551e-02, 0.0000e+00],
#         [2.5525e+02, 9.6579e+01, 4.1542e+02, 5.0469e+02, 1.5051e-03, 0.0000e+00]], device='cuda:0')
# Individual Detection result: [255.25611877441406, 0.94744873046875, 441.59375, 503.67144775390625, 0.6819528937339783, 0.0]
# Prediction bbox: 255 1 442 504, Conf: 0.682, Pred_label: bark
# Individual Detection result: [255.36456298828125, 3.04241943359375, 637.48876953125, 506.38214111328125, 0.09855115413665771, 0.0]
# Prediction bbox: 255 3 637 506, Conf: 0.099, Pred_label: bark
# Individual Detection result: [255.25486755371094, 96.57868957519531, 415.423828125, 504.69427490234375, 0.0015050697838887572, 0.0]
# Prediction bbox: 255 97 415 505, Conf: 0.002, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36455_73530109_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: bark -> GT: bark IOU: 0.9135105053708118
# No best match found for Pred: bark
# No best match found for Pred: bark
# Annotated image saved to: inference/run_20251205_110700/false_positives/36455_73530109_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36455_73530109_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9935708.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9935708.txt
#
# Label File content (GT): [2.0, 0.388608, 0.444304, 0.604219, 0.648101]
# GT Box (yolo to xyxy): [32, 60, 259, 384]
#
# --- Pipeline inference ---
#
# 0: 640x480 1 crested_anole, 24.0ms
# Speed: 1.8ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Raw Detection result: tensor([[ 30.3268,  60.7298, 259.4459, 383.5202,   0.9353,   2.0000]], device='cuda:0')
# Individual Detection result: [30.32684326171875, 60.72975540161133, 259.4458923339844, 383.5201721191406, 0.9352823495864868, 2.0]
# Prediction bbox: 30 61 259 384, Conf: 0.935, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_9935708_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9882335498827398
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_97562261.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_97562261.txt
#
# Label File content (GT): [4.0, 0.35703125, 0.3671875, 0.28984375, 0.65]
# GT Box (yolo to xyxy): [136, 27, 321, 443]
#
# --- Pipeline inference ---
#
# 0: 640x640 3 knight_anoles, 29.2ms
# Speed: 1.3ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.3659e+02, 2.6250e+01, 3.2276e+02, 4.9742e+02, 8.4928e-01, 4.0000e+00],
#         [1.4438e+02, 2.1989e+01, 4.0594e+02, 6.3991e+02, 3.6453e-01, 4.0000e+00],
#         [2.5294e+02, 2.7486e+02, 3.9283e+02, 6.4000e+02, 3.6285e-03, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [136.59088134765625, 26.249847412109375, 322.76324462890625, 497.4208068847656, 0.8492794036865234, 4.0]
# Prediction bbox: 137 26 323 497, Conf: 0.849, Pred_label: knight
# Individual Detection result: [144.3842010498047, 21.9886474609375, 405.93511962890625, 639.9114990234375, 0.36452987790107727, 4.0]
# Prediction bbox: 144 22 406 639, Conf: 0.365, Pred_label: knight
# Individual Detection result: [252.9388885498047, 274.85662841796875, 392.83489990234375, 640.0, 0.0036284972447901964, 4.0]
# Prediction bbox: 253 275 393 639, Conf: 0.004, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36391_97562261_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.8696007816227761
# No best match found for Pred: knight
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_97562261_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36391_97562261_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_95877932.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_95877932.txt
#
# Label File content (GT): [4.0, 0.586348, 0.750087, 0.66, 0.492174]
# GT Box (yolo to xyxy): [128, 189, 458, 374]
#
# --- Pipeline inference ---
#
# 0: 480x640 2 knight_anoles, 66.2ms
# Speed: 1.8ms preprocess, 66.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Raw Detection result: tensor([[1.0717e+02, 1.8659e+02, 4.5845e+02, 3.7499e+02, 9.3492e-01, 4.0000e+00],
#         [1.3003e+02, 1.8568e+02, 4.5909e+02, 3.0814e+02, 2.2542e-03, 4.0000e+00]], device='cuda:0')
# ...
# Prediction bbox: 20 76 541 528, Conf: 0.005, Pred_label: green
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36514_632856_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.6508611745175348
# No best match found for Pred: green
# No best match found for Pred: knight
# No best match found for Pred: green
# No best match found for Pred: green
# Annotated image saved to: inference/run_20251205_110700/false_positives/36514_632856_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36514_632856_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36514_632856_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/36514_632856_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_9932138.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_9932138.txt
#
# Label File content (GT): [0.0, 0.37265625, 0.47578125, 0.11640625, 0.4703125]
# GT Box (yolo to xyxy): [201, 154, 276, 455]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.5ms
# Speed: 1.6ms preprocess, 28.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.0356e+02, 1.5151e+02, 2.7975e+02, 5.7858e+02, 4.2039e-01, 2.0000e+00]], device='cuda:0')
# Individual Detection result: [203.5599365234375, 151.51271057128906, 279.75433349609375, 578.5791015625, 0.4203932285308838, 2.0]
# Prediction bbox: 204 152 280 579, Conf: 0.420, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36455_9932138_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: bark IOU: 0.6497376705141658
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110700/mis_classification/36455_9932138_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9879756.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9879756.txt
#
# Label File content (GT): [1.0, 0.49765625, 0.57109375, 0.17265625, 0.20625]
# GT Box (yolo to xyxy): [263, 300, 374, 432]
#
# --- Pipeline inference ---
#
# 0: 640x640 2 bark_anoles, 2 brown_anoles, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.5316e+02, 2.9879e+02, 3.7104e+02, 4.3174e+02, 8.9767e-01, 1.0000e+00],
#         [2.6412e+02, 3.4271e+02, 3.6107e+02, 4.3123e+02, 3.6813e-03, 0.0000e+00],
#         [2.5395e+02, 2.9905e+02, 3.7330e+02, 5.2794e+02, 3.1954e-03, 1.0000e+00],
#         [2.8022e+02, 3.5769e+02, 3.7014e+02, 4.2999e+02, 1.0813e-03, 0.0000e+00]], device='cuda:0')
# Individual Detection result: [253.1561737060547, 298.78619384765625, 371.03839111328125, 431.73974609375, 0.8976687788963318, 1.0]
# Prediction bbox: 253 299 371 432, Conf: 0.898, Pred_label: brown
# Individual Detection result: [264.12139892578125, 342.70513916015625, 361.07427978515625, 431.22613525390625, 0.0036812820471823215, 0.0]
# Prediction bbox: 264 343 361 431, Conf: 0.004, Pred_label: bark
# Individual Detection result: [253.9454345703125, 299.0472412109375, 373.29656982421875, 527.938232421875, 0.003195434343069792, 1.0]
# Prediction bbox: 254 299 373 528, Conf: 0.003, Pred_label: brown
# Individual Detection result: [280.2156982421875, 357.68756103515625, 370.14312744140625, 429.98577880859375, 0.0010813325643539429, 0.0]
# Prediction bbox: 280 358 370 430, Conf: 0.001, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110700/annotated_images/116461_9879756_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.8860161591050342
# No best match found for Pred: bark
# No best match found for Pred: brown
# No best match found for Pred: bark
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9879756_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9879756_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9879756_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9952804.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9952804.txt
#
# Label File content (GT): [1.0, 0.6515625, 0.47578125, 0.690625, 0.36171875]
# GT Box (yolo to xyxy): [196, 189, 638, 420]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 bark_anole, 1 brown_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.9502e+02, 1.8604e+02, 6.4000e+02, 4.5802e+02, 6.4912e-01, 1.0000e+00],
#         [1.9608e+02, 1.8641e+02, 6.4000e+02, 6.2093e+02, 5.5573e-02, 0.0000e+00]], device='cuda:0')
# Individual Detection result: [195.02398681640625, 186.03610229492188, 640.0, 458.0204162597656, 0.6491182446479797, 1.0]
# Prediction bbox: 195 186 639 458, Conf: 0.649, Pred_label: brown
# Individual Detection result: [196.08290100097656, 186.40797424316406, 640.0, 620.927734375, 0.05557287484407425, 0.0]
# Prediction bbox: 196 186 639 621, Conf: 0.056, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110700/annotated_images/116461_9952804_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.8454391891891891
# No best match found for Pred: bark
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9952804_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9935900.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9935900.txt
#
# Label File content (GT): [2.0, 0.4953125, 0.55078125, 0.5578125, 0.22109375]
# GT Box (yolo to xyxy): [138, 282, 496, 423]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.5ms
# Speed: 1.4ms preprocess, 28.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[ 99.4372, 283.1486, 496.0065, 423.3747,   0.8844,   2.0000]], device='cuda:0')
# Individual Detection result: [99.43724060058594, 283.14862060546875, 496.0064697265625, 423.37469482421875, 0.8843693137168884, 2.0]
# Prediction bbox: 99 283 496 423, Conf: 0.884, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_9935900_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.8959919911330402
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9938205.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9938205.txt
#
# Label File content (GT): [1.0, 0.6171875, 0.315625, 0.62109375, 0.1796875]
# GT Box (yolo to xyxy): [196, 144, 594, 260]
#
# --- Pipeline inference ---
#
# 0: 640x640 3 brown_anoles, 28.5ms
# Speed: 1.4ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.9676e+02, 1.4436e+02, 5.9314e+02, 2.5771e+02, 9.1354e-01, 1.0000e+00],
#         [1.9686e+02, 1.4419e+02, 5.9224e+02, 3.0744e+02, 6.4717e-03, 1.0000e+00],
#         [1.9473e+02, 1.4501e+02, 5.9199e+02, 5.2009e+02, 2.3092e-03, 1.0000e+00]], device='cuda:0')
# Individual Detection result: [196.75921630859375, 144.36166381835938, 593.138671875, 257.7115478515625, 0.9135361909866333, 1.0]
# Prediction bbox: 197 144 593 258, Conf: 0.914, Pred_label: brown
# Individual Detection result: [196.8603515625, 144.19110107421875, 592.2355346679688, 307.4444580078125, 0.00647168280556798, 1.0]
# Prediction bbox: 197 144 592 307, Conf: 0.006, Pred_label: brown
# Individual Detection result: [194.7291717529297, 145.01025390625, 591.9906616210938, 520.091064453125, 0.0023092259652912617, 1.0]
# Prediction bbox: 195 145 592 520, Conf: 0.002, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110700/annotated_images/116461_9938205_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.9778201351585514
# No best match found for Pred: brown
# No best match found for Pred: brown
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9938205_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9938205_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9937794.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9937794.txt
#
# Label File content (GT): [1.0, 0.4875, 0.56015625, 0.42578125, 0.19765625]
# GT Box (yolo to xyxy): [176, 295, 448, 422]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 brown_anole, 2 green_anoles, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.7345e+02, 3.0081e+02, 4.4808e+02, 4.2053e+02, 7.0497e-01, 3.0000e+00],
#         [1.6972e+02, 2.1896e+02, 4.4809e+02, 4.2249e+02, 1.2030e-03, 1.0000e+00],
#         [6.0713e+02, 1.5918e+02, 6.4000e+02, 2.7910e+02, 1.1328e-03, 3.0000e+00]], device='cuda:0')
# Individual Detection result: [173.4451141357422, 300.8126220703125, 448.08184814453125, 420.52508544921875, 0.7049704194068909, 3.0]
# Prediction bbox: 173 301 448 421, Conf: 0.705, Pred_label: green
# Individual Detection result: [169.7180633544922, 218.9553985595703, 448.09307861328125, 422.48699951171875, 0.001203027437441051, 1.0]
# Prediction bbox: 170 219 448 422, Conf: 0.001, Pred_label: brown
# Individual Detection result: [607.1286010742188, 159.17987060546875, 640.0, 279.1015625, 0.0011328149121254683, 3.0]
# Prediction bbox: 607 159 639 279, Conf: 0.001, Pred_label: green
# Annotated image saved to: inference/run_20251205_110700/annotated_images/116461_9937794_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: brown IOU: 0.9351363740545496
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110700/mis_classification/116461_9937794_annotated.jpg
# No best match found for Pred: brown
# No best match found for Pred: green
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9937794_annotated.jpg
# Annotated image saved to: inference/run_20251205_110700/false_positives/116461_9937794_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_77845172.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_77845172.txt
#
# Label File content (GT): [2.0, 0.59296875, 0.575, 0.79765625, 0.328125]
# GT Box (yolo to xyxy): [124, 263, 635, 473]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 brown_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[125.2851, 262.4339, 638.9731, 469.2704,   0.7184,   1.0000]], device='cuda:0')
# Individual Detection result: [125.28509521484375, 262.4339294433594, 638.9730834960938, 469.2703552246094, 0.7183976769447327, 1.0]
# Prediction bbox: 125 262 639 469, Conf: 0.718, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110700/annotated_images/36488_77845172_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: crested IOU: 0.966975922244312
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110700/mis_classification/36488_77845172_annotated.jpg
#
# Saved evaluation results to inference/run_20251205_110700/eval_results.csv
#               precision    recall  f1-score   support
#
#         bark       0.37      0.73      0.49       202
#        brown       0.36      0.67      0.47       200
#      crested       0.42      0.75      0.54       204
#        green       0.27      0.75      0.39       203
#       knight       0.28      0.88      0.42       202
#   Background       0.00      0.00      0.00      1372
#
#     accuracy                           0.32      2383
#    macro avg       0.28      0.63      0.38      2383
# weighted avg       0.14      0.32      0.20      2383
#
#
# --- Detection mAP Evaluation ---
#
# Evaluating AP at IoU = 0.50
#   AP for class 'bark' (id=0) at IoU=0.50: 0.6931
#   AP for class 'brown' (id=1) at IoU=0.50: 0.5708
#   AP for class 'crested' (id=2) at IoU=0.50: 0.6577
#   AP for class 'green' (id=3) at IoU=0.50: 0.6829
#   AP for class 'knight' (id=4) at IoU=0.50: 0.7752
#
# Evaluating AP at IoU = 0.55
#   AP for class 'bark' (id=0) at IoU=0.55: 0.6827
#   AP for class 'brown' (id=1) at IoU=0.55: 0.5404
#   AP for class 'crested' (id=2) at IoU=0.55: 0.6567
#   AP for class 'green' (id=3) at IoU=0.55: 0.6688
#   AP for class 'knight' (id=4) at IoU=0.55: 0.7574
#
# Evaluating AP at IoU = 0.60
#   AP for class 'bark' (id=0) at IoU=0.60: 0.6710
#   AP for class 'brown' (id=1) at IoU=0.60: 0.5223
#   AP for class 'crested' (id=2) at IoU=0.60: 0.6540
#   AP for class 'green' (id=3) at IoU=0.60: 0.6607
#   AP for class 'knight' (id=4) at IoU=0.60: 0.7498
#
# Evaluating AP at IoU = 0.65
#   AP for class 'bark' (id=0) at IoU=0.65: 0.6531
#   AP for class 'brown' (id=1) at IoU=0.65: 0.4995
#   AP for class 'crested' (id=2) at IoU=0.65: 0.6463
#   AP for class 'green' (id=3) at IoU=0.65: 0.6436
#   AP for class 'knight' (id=4) at IoU=0.65: 0.7212
#
# Evaluating AP at IoU = 0.70
#   AP for class 'bark' (id=0) at IoU=0.70: 0.6485
#   AP for class 'brown' (id=1) at IoU=0.70: 0.4628
#   AP for class 'crested' (id=2) at IoU=0.70: 0.6446
#   AP for class 'green' (id=3) at IoU=0.70: 0.6100
#   AP for class 'knight' (id=4) at IoU=0.70: 0.6569
#
# Evaluating AP at IoU = 0.75
#   AP for class 'bark' (id=0) at IoU=0.75: 0.6356
#   AP for class 'brown' (id=1) at IoU=0.75: 0.4322
#   AP for class 'crested' (id=2) at IoU=0.75: 0.6411
#   AP for class 'green' (id=3) at IoU=0.75: 0.5649
#   AP for class 'knight' (id=4) at IoU=0.75: 0.6259
#
# Evaluating AP at IoU = 0.80
#   AP for class 'bark' (id=0) at IoU=0.80: 0.5831
#   AP for class 'brown' (id=1) at IoU=0.80: 0.3732
#   AP for class 'crested' (id=2) at IoU=0.80: 0.6224
#   AP for class 'green' (id=3) at IoU=0.80: 0.4752
#   AP for class 'knight' (id=4) at IoU=0.80: 0.5633
#
# Evaluating AP at IoU = 0.85
#   AP for class 'bark' (id=0) at IoU=0.85: 0.4414
#   AP for class 'brown' (id=1) at IoU=0.85: 0.3061
#   AP for class 'crested' (id=2) at IoU=0.85: 0.5841
#   AP for class 'green' (id=3) at IoU=0.85: 0.4093
#   AP for class 'knight' (id=4) at IoU=0.85: 0.5139
#
# Evaluating AP at IoU = 0.90
#   AP for class 'bark' (id=0) at IoU=0.90: 0.3036
#   AP for class 'brown' (id=1) at IoU=0.90: 0.2373
#   AP for class 'crested' (id=2) at IoU=0.90: 0.4804
#   AP for class 'green' (id=3) at IoU=0.90: 0.3535
#   AP for class 'knight' (id=4) at IoU=0.90: 0.4292
#
# Evaluating AP at IoU = 0.95
#   AP for class 'bark' (id=0) at IoU=0.95: 0.1170
#   AP for class 'brown' (id=1) at IoU=0.95: 0.0895
#   AP for class 'crested' (id=2) at IoU=0.95: 0.2887
#   AP for class 'green' (id=3) at IoU=0.95: 0.1982
#   AP for class 'knight' (id=4) at IoU=0.95: 0.2326
#
# --- Summary mAP ---
# mAP@0.50      : 0.6759
# mAP@0.75      : 0.5799
# mAP@0.50:0.95 : 0.5326
#
# --- Plotting Precision-Recall Curves at IoU = 0.50 ---
# Saved Precision-Recall curves to: inference/run_20251205_110700/pr_curves_iou_50.png

# %% [markdown]
# ### Evaluate for Confusion Matrix

# %%
evaluate_performance(yolo_model_file_path="./runs/detect/train22_yolov12x_dataset_v4/weights/best.pt",
    swin_model_file_path=None, det_conf_thresh=0.3, nms_iou_thresh=0.7, eval_iou_thresh = 0.5, top_k=5)
# Out:
# --- EVALUATION PIPELINE ---
# YOLO Model Config: NMS_IOU_THRESHOLD: 0.7
#  CONF_THRESH: 0.3
#  MAX_DETECTION: 5
#
# EVAL Config: EVAL_IOU_THRESHOLD: 0.5
#
# --- LOADING MODELS ---
# YOLO_MODEL_FILE_PATH: ./runs/detect/train22_yolov12x_dataset_v4/weights/best.pt
#
# --- COMPLETED LOADING MODELS ---
# --- Saving results and debug images to inference/run_20251205_110753 ---
#
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9891309.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9891309.txt
#
# Label File content (GT): [1.0, 0.25234375, 0.42734375, 0.50390625, 0.25]
# GT Box (yolo to xyxy): [0, 194, 323, 354]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 brown_anole, 28.5ms
# Speed: 1.6ms preprocess, 28.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[  2.2191, 197.0715, 322.4495, 348.7940,   0.7905,   1.0000]], device='cuda:0')
# Individual Detection result: [2.219146728515625, 197.07150268554688, 322.4494934082031, 348.7940368652344, 0.7905368804931641, 1.0]
# Prediction bbox: 2 197 322 349, Conf: 0.791, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9891309_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.9411764705882353
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_893241.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_893241.txt
#
# Label File content (GT): [3.0, 0.48515625, 0.64296875, 0.30390625, 0.70234375]
# GT Box (yolo to xyxy): [213, 187, 408, 636]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.6ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[194.1234, 186.7590, 408.2986, 639.7014,   0.8333,   3.0000]], device='cuda:0')
# Individual Detection result: [194.12335205078125, 186.75897216796875, 408.29864501953125, 639.701416015625, 0.8332821130752563, 3.0]
# Prediction bbox: 194 187 408 639, Conf: 0.833, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_893241_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.9051670664130345
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_82799705.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_82799705.txt
#
# Label File content (GT): [4.0, 0.46796875, 0.44921875, 0.20234375, 0.28984375]
# GT Box (yolo to xyxy): [235, 195, 364, 380]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[226.8914, 189.0914, 378.4768, 370.1260,   0.4522,   4.0000]], device='cuda:0')
# Individual Detection result: [226.89138793945312, 189.0914306640625, 378.4768371582031, 370.12603759765625, 0.452229380607605, 4.0]
# Prediction bbox: 227 189 378 370, Conf: 0.452, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_82799705_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.7887565074595577
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_96732137.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_96732137.txt
#
# Label File content (GT): [4.0, 0.51015625, 0.31328125, 0.66015625, 0.6265625]
# GT Box (yolo to xyxy): [115, 0, 538, 401]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.5ms
# Speed: 1.4ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[121.6048,   0.0000, 549.2677, 633.9814,   0.8080,   4.0000]], device='cuda:0')
# Individual Detection result: [121.60479736328125, 0.0, 549.2677001953125, 633.9813842773438, 0.8079913854598999, 4.0]
# Prediction bbox: 122 0 549 634, Conf: 0.808, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_96732137_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.6098747829266064
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_91198274.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_91198274.txt
#
# Label File content (GT): [4.0, 0.63203125, 0.5671875, 0.73046875, 0.4578125]
# GT Box (yolo to xyxy): [171, 216, 638, 510]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[172.5309, 218.3321, 438.3919, 383.0672,   0.5005,   4.0000]], device='cuda:0')
# Individual Detection result: [172.5308837890625, 218.33206176757812, 438.39190673828125, 383.0671691894531, 0.5005197525024414, 4.0]
# Prediction bbox: 173 218 438 383, Conf: 0.501, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_91198274_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110753/missed_detections/36391_91198274_annotated.jpg
# Annotated image saved to: inference/run_20251205_110753/false_positives/36391_91198274_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_95815604.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_95815604.txt
#
# Label File content (GT): [2.0, 0.50390625, 0.47109375, 0.93671875, 0.9421875]
# GT Box (yolo to xyxy): [23, 0, 622, 603]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[ 21.6434,   0.0000, 628.1880, 606.9562,   0.8886,   2.0000]], device='cuda:0')
# Individual Detection result: [21.64337158203125, 0.0, 628.18798828125, 606.9561767578125, 0.8885648250579834, 2.0]
# Prediction bbox: 22 0 628 607, Conf: 0.889, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_95815604_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.981935178690851
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_84714837.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_84714837.txt
#
# Label File content (GT): [4.0, 0.43046875, 0.50625, 0.8609375, 0.25]
# GT Box (yolo to xyxy): [0, 244, 551, 404]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[  0.0000, 237.8634, 552.5665, 403.3216,   0.9190,   4.0000]], device='cuda:0')
# Individual Detection result: [0.0, 237.8633575439453, 552.5665283203125, 403.32159423828125, 0.9190400838851929, 4.0]
# Prediction bbox: 0 238 553 403, Conf: 0.919, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_84714837_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.9543879907621247
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9891671.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9891671.txt
#
# Label File content (GT): [1.0, 0.4109375, 0.5078125, 0.309375, 0.05625]
# GT Box (yolo to xyxy): [164, 307, 362, 343]
#
# --- Pipeline inference ---
# 0: 640x640 1 brown_anole, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[166.6586, 306.8195, 361.3626, 346.5358,   0.8639,   1.0000]], device='cuda:0')
# Individual Detection result: [166.6586151123047, 306.81951904296875, 361.36260986328125, 346.53582763671875, 0.863875687122345, 1.0]
# Prediction bbox: 167 307 361 347, Conf: 0.864, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9891671_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.8836032388663968
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_92824180.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_92824180.txt
#
# Label File content (GT): [4.0, 0.58515625, 0.475, 0.12265625, 0.246875]
# GT Box (yolo to xyxy): [335, 225, 414, 383]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[329.2411, 230.5374, 413.1867, 383.9005,   0.9154,   4.0000]], device='cuda:0')
# Individual Detection result: [329.2411193847656, 230.537353515625, 413.1867370605469, 383.9005126953125, 0.9153674840927124, 4.0]
# Prediction bbox: 329 231 413 384, Conf: 0.915, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_92824180_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.8796557352722956
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_85657940.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_85657940.txt
#
# Label File content (GT): [4.0, 0.501623, 0.55113, 0.387246, 0.897739]
# GT Box (yolo to xyxy): [116, 51, 261, 499]
#
# --- Pipeline inference ---
#
# 0: 640x480 1 knight_anole, 23.9ms
# Speed: 1.9ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Raw Detection result: tensor([[118.9473,  55.2375, 275.1701, 500.0000,   0.9186,   4.0000]], device='cuda:0')
# Individual Detection result: [118.94731140136719, 55.23753356933594, 275.1701354980469, 500.0, 0.9186434149742126, 4.0]
# Prediction bbox: 119 55 275 499, Conf: 0.919, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_85657940_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.8858042036641565
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9811279.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9811279.txt
#
# Label File content (GT): [2.0, 0.4890625, 0.5046875, 0.31875, 0.821875]
# GT Box (yolo to xyxy): [211, 60, 415, 586]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 29.2ms
# Speed: 1.4ms preprocess, 29.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[207.9482,  61.7291, 417.6486, 585.1415,   0.8956,   2.0000]], device='cuda:0')
# Individual Detection result: [207.94818115234375, 61.72906494140625, 417.64862060546875, 585.1415405273438, 0.8955536484718323, 2.0]
# Prediction bbox: 208 62 418 585, Conf: 0.896, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_9811279_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9660455261585267
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_70774235.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_70774235.txt
#
# Label File content (GT): [0.0, 0.6265625, 0.496875, 0.22421875, 0.49765625]
# GT Box (yolo to xyxy): [329, 159, 473, 477]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 bark_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[329.5589, 157.1558, 478.0306, 477.8622,   0.9361,   0.0000]], device='cuda:0')
# Individual Detection result: [329.55889892578125, 157.15576171875, 478.03057861328125, 477.86224365234375, 0.93613201379776, 0.0]
# Prediction bbox: 330 157 478 478, Conf: 0.936, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36455_70774235_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: bark -> GT: bark IOU: 0.9508217287667796
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9925551.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9925551.txt
#
# Label File content (GT): [1.0, 0.4953125, 0.29375, 0.30078125, 0.0875]
# GT Box (yolo to xyxy): [221, 160, 413, 216]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[220.3508, 158.4833, 415.4408, 215.9937,   0.8853,   4.0000]], device='cuda:0')
# Individual Detection result: [220.35076904296875, 158.4832763671875, 415.4407958984375, 215.99365234375, 0.8852859735488892, 4.0]
# Prediction bbox: 220 158 415 216, Conf: 0.885, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9925551_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: brown IOU: 0.9506631299734748
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110753/mis_classification/116461_9925551_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_94470018.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_94470018.txt
#
# Label File content (GT): [4.0, 0.3453125, 0.6546875, 0.690625, 0.6859375]
# GT Box (yolo to xyxy): [0, 200, 442, 638]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.5ms
# Speed: 1.4ms preprocess, 28.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[  0.7428, 197.3431, 441.0475, 639.2057,   0.9677,   4.0000]], device='cuda:0')
# Individual Detection result: [0.742767333984375, 197.3431396484375, 441.0475158691406, 639.2056884765625, 0.9677172899246216, 4.0]
# Prediction bbox: 1 197 441 639, Conf: 0.968, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_94470018_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.9865066852310653
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_613168.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_613168.txt
#
# Label File content (GT): [3.0, 0.490625, 0.5359375, 0.55234375, 0.92421875]
# GT Box (yolo to xyxy): [137, 47, 491, 639]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[141.3590,  47.4975, 501.9824, 639.9526,   0.9395,   3.0000]], device='cuda:0')
# Individual Detection result: [141.3590087890625, 47.49749755859375, 501.982421875, 639.9525756835938, 0.9394688010215759, 3.0]
# Prediction bbox: 141 47 502 639, Conf: 0.939, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_613168_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.958904109589041
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_81505029.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_81505029.txt
#
# Label File content (GT): [4.0, 0.47421875, 0.54375, 0.94765625, 0.85390625]
# GT Box (yolo to xyxy): [0, 75, 607, 621]
#
# --- Pipeline inference ---
# 0: 640x640 2 knight_anoles, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.7418e+02, 7.7469e+01, 6.0842e+02, 5.4317e+02, 9.2512e-01, 4.0000e+00],
#         [1.1209e+00, 7.3427e+01, 6.0996e+02, 6.0950e+02, 5.3825e-01, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [274.18267822265625, 77.46923828125, 608.4205932617188, 543.166259765625, 0.9251232743263245, 4.0]
# Prediction bbox: 274 77 608 543, Conf: 0.925, Pred_label: knight
# Individual Detection result: [1.12091064453125, 73.42718505859375, 609.9553833007812, 609.5031127929688, 0.5382500886917114, 4.0]
# Prediction bbox: 1 73 610 610, Conf: 0.538, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_81505029_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: knight
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.9699771125970471
# Annotated image saved to: inference/run_20251205_110753/false_positives/36391_81505029_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_97023199.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_97023199.txt
#
# Label File content (GT): [4.0, 0.63671875, 0.57890625, 0.71171875, 0.6296875]
# GT Box (yolo to xyxy): [180, 169, 635, 572]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[179.2446, 166.0055, 639.8887, 574.7374,   0.9601,   4.0000]], device='cuda:0')
# Individual Detection result: [179.24464416503906, 166.0054931640625, 639.888671875, 574.7374267578125, 0.9601156115531921, 4.0]
# Prediction bbox: 179 166 639 575, Conf: 0.960, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_97023199_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.9746199638567025
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_85134369.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_85134369.txt
#
# Label File content (GT): [2.0, 0.4828125, 0.521875, 0.965625, 0.58828125]
# GT Box (yolo to xyxy): [0, 146, 618, 522]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[  0.8512, 144.5353, 620.9907, 522.7133,   0.8808,   2.0000]], device='cuda:0')
# Individual Detection result: [0.8511962890625, 144.5352783203125, 620.99072265625, 522.7132568359375, 0.8808454275131226, 2.0]
# Prediction bbox: 1 145 621 523, Conf: 0.881, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_85134369_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9883102719651012
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_76820250.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_76820250.txt
#
# Label File content (GT): [2.0, 0.4640625, 0.565625, 0.3203125, 0.8109375]
# GT Box (yolo to xyxy): [194, 102, 400, 622]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.5ms
# Speed: 1.4ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[196.1821, 104.3205, 399.8879, 624.4648,   0.8524,   2.0000]], device='cuda:0')
# Individual Detection result: [196.18211364746094, 104.32049560546875, 399.887939453125, 624.46484375, 0.852373480796814, 2.0]
# Prediction bbox: 196 104 400 624, Conf: 0.852, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_76820250_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9827393795104531
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9938238.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9938238.txt
#
# Label File content (GT): [2.0, 0.385232, 0.181013, 0.455696, 0.210127]
# GT Box (yolo to xyxy): [59, 38, 230, 143]
#
# --- Pipeline inference ---
#
# 0: 640x480 1 crested_anole, 24.0ms
# Speed: 1.9ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Raw Detection result: tensor([[ 35.7968,  49.8052, 234.6222, 143.9908,   0.8173,   2.0000]], device='cuda:0')
# Individual Detection result: [35.79677963256836, 49.80522537231445, 234.6222381591797, 143.9908447265625, 0.8172851204872131, 2.0]
# Prediction bbox: 36 50 235 144, Conf: 0.817, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_9938238_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.7661142691974179
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_9538375.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_9538375.txt
#
# Label File content (GT): [4.0, 0.5640625, 0.46875, 0.86640625, 0.33828125]
# GT Box (yolo to xyxy): [84, 192, 638, 408]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 bark_anole, 29.2ms
# Speed: 1.4ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[3.0355e+02, 2.3391e+02, 4.3226e+02, 3.0874e+02, 4.2218e-01, 0.0000e+00]], device='cuda:0')
# Individual Detection result: [303.5458679199219, 233.906982421875, 432.2601623535156, 308.73565673828125, 0.4221831262111664, 0.0]
# Prediction bbox: 304 234 432 309, Conf: 0.422, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_9538375_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: bark
# Annotated image saved to: inference/run_20251205_110753/missed_detections/36391_9538375_annotated.jpg
# Annotated image saved to: inference/run_20251205_110753/false_positives/36391_9538375_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_577947.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_577947.txt
#
# Label File content (GT): [3.0, 0.4921875, 0.6640625, 0.23203125, 0.65625]
# GT Box (yolo to xyxy): [241, 215, 389, 635]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[237.9362, 216.0599, 391.4650, 639.7961,   0.9052,   3.0000]], device='cuda:0')
# Individual Detection result: [237.9361572265625, 216.05987548828125, 391.46502685546875, 639.7960815429688, 0.9052202105522156, 3.0]
# Prediction bbox: 238 216 391 639, Conf: 0.905, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_577947_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.9559868654323462
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_850152.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_850152.txt
#
# Label File content (GT): [3.0, 0.446875, 0.4734375, 0.23125, 0.575]
# GT Box (yolo to xyxy): [212, 119, 360, 487]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[249.6374, 119.4442, 359.0204, 482.8085,   0.9395,   3.0000]], device='cuda:0')
# Individual Detection result: [249.63742065429688, 119.4442138671875, 359.0204162597656, 482.8084716796875, 0.9394591450691223, 3.0]
# Prediction bbox: 250 119 359 483, Conf: 0.939, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_850152_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.7284811985898942
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_75082114.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_75082114.txt
#
# Label File content (GT): [2.0, 0.5375, 0.47109375, 0.64296875, 0.59765625]
# GT Box (yolo to xyxy): [138, 110, 550, 493]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[138.5648, 109.9212, 553.0391, 495.3536,   0.9431,   2.0000]], device='cuda:0')
# Individual Detection result: [138.56475830078125, 109.92121887207031, 553.0390625, 495.35357666015625, 0.9431416392326355, 2.0]
# Prediction bbox: 139 110 553 495, Conf: 0.943, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_75082114_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9852290437057576
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_613970.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_613970.txt
#
# Label File content (GT): [3.0, 0.559375, 0.52421875, 0.4296875, 0.76015625]
# GT Box (yolo to xyxy): [220, 92, 496, 579]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[218.4639,  92.2137, 539.7923, 638.8016,   0.9451,   3.0000]], device='cuda:0')
# Individual Detection result: [218.4638671875, 92.21368408203125, 539.7922973632812, 638.8015747070312, 0.9450724720954895, 3.0]
# Prediction bbox: 218 92 540 639, Conf: 0.945, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_613970_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.7631235309480282
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_73530109.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_73530109.txt
#
# Label File content (GT): [0.0, 0.5328125, 0.39140625, 0.27578125, 0.7828125]
# GT Box (yolo to xyxy): [253, 0, 429, 501]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 bark_anole, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[255.2561,   0.9474, 441.5938, 503.6714,   0.6820,   0.0000]], device='cuda:0')
# Individual Detection result: [255.25611877441406, 0.94744873046875, 441.59375, 503.67144775390625, 0.6819528937339783, 0.0]
# Prediction bbox: 255 1 442 504, Conf: 0.682, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36455_73530109_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: bark -> GT: bark IOU: 0.9135105053708118
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9935708.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9935708.txt
#
# Label File content (GT): [2.0, 0.388608, 0.444304, 0.604219, 0.648101]
# GT Box (yolo to xyxy): [32, 60, 259, 384]
#
# --- Pipeline inference ---
#
# 0: 640x480 1 crested_anole, 24.0ms
# Speed: 1.9ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Raw Detection result: tensor([[ 30.3268,  60.7298, 259.4459, 383.5202,   0.9353,   2.0000]], device='cuda:0')
# Individual Detection result: [30.32684326171875, 60.72975540161133, 259.4458923339844, 383.5201721191406, 0.9352823495864868, 2.0]
# Prediction bbox: 30 61 259 384, Conf: 0.935, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_9935708_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9882335498827398
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_97562261.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_97562261.txt
#
# Label File content (GT): [4.0, 0.35703125, 0.3671875, 0.28984375, 0.65]
# GT Box (yolo to xyxy): [136, 27, 321, 443]
#
# --- Pipeline inference ---
#
# 0: 640x640 2 knight_anoles, 29.2ms
# Speed: 1.5ms preprocess, 29.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[1.3659e+02, 2.6250e+01, 3.2276e+02, 4.9742e+02, 8.4928e-01, 4.0000e+00],
#         [1.4438e+02, 2.1989e+01, 4.0594e+02, 6.3991e+02, 3.6453e-01, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [136.59088134765625, 26.249847412109375, 322.76324462890625, 497.4208068847656, 0.8492794036865234, 4.0]
# Prediction bbox: 137 26 323 497, Conf: 0.849, Pred_label: knight
# Individual Detection result: [144.3842010498047, 21.9886474609375, 405.93511962890625, 639.9114990234375, 0.36452987790107727, 4.0]
# Prediction bbox: 144 22 406 639, Conf: 0.365, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_97562261_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.8696007816227761
# No best match found for Pred: knight
# Annotated image saved to: inference/run_20251205_110753/false_positives/36391_97562261_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_95877932.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_95877932.txt
#
# Label File content (GT): [4.0, 0.586348, 0.750087, 0.66, 0.492174]
# GT Box (yolo to xyxy): [128, 189, 458, 374]
#
# --- Pipeline inference ---
#
# 0: 480x640 1 knight_anole, 23.9ms
# Speed: 1.8ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Raw Detection result: tensor([[107.1683, 186.5916, 458.4463, 374.9879,   0.9349,   4.0000]], device='cuda:0')
# Individual Detection result: [107.16834259033203, 186.59158325195312, 458.4463195800781, 374.9878845214844, 0.9349242448806763, 4.0]
# Prediction bbox: 107 187 458 374, Conf: 0.935, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_95877932_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.930115635997989
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_89799786.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_89799786.txt
#
# Label File content (GT): [4.0, 0.45, 0.478125, 0.45, 0.628125]
# GT Box (yolo to xyxy): [144, 105, 432, 507]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 29.2ms
# Speed: 1.4ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[146.4583, 108.6619, 436.3847, 509.9492,   0.8350,   4.0000]], device='cuda:0')
# Individual Detection result: [146.45831298828125, 108.66189575195312, 436.38470458984375, 509.9491882324219, 0.8349994421005249, 4.0]
# Prediction bbox: 146 109 436 510, Conf: 0.835, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_89799786_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.962702346115462
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9881959.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9881959.txt
#
# Label File content (GT): [1.0, 0.54296875, 0.4265625, 0.31171875, 0.13046875]
# GT Box (yolo to xyxy): [248, 231, 447, 315]
#
# --- Pipeline inference ---
# 0: 640x640 1 brown_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[246.3777, 227.1580, 405.5032, 308.9114,   0.5495,   1.0000]], device='cuda:0')
# Individual Detection result: [246.37774658203125, 227.157958984375, 405.50323486328125, 308.91143798828125, 0.5494963526725769, 1.0]
# Prediction bbox: 246 227 406 309, Conf: 0.549, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9881959_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.7037460027409776
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_754144.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_754144.txt
#
# Label File content (GT): [3.0, 0.4765625, 0.7109375, 0.246875, 0.57734375]
# GT Box (yolo to xyxy): [226, 270, 384, 639]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[221.9776, 262.1127, 385.2529, 637.8157,   0.8541,   3.0000]], device='cuda:0')
# Individual Detection result: [221.9776153564453, 262.11273193359375, 385.25286865234375, 637.8157348632812, 0.8540840148925781, 3.0]
# Prediction bbox: 222 262 385 638, Conf: 0.854, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_754144_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.9462617582918335
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_76571017.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_76571017.txt
#
# Label File content (GT): [2.0, 0.50234375, 0.475, 0.284375, 0.6859375]
# GT Box (yolo to xyxy): [230, 84, 412, 524]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[227.9437,  57.1023, 415.8994, 524.9330,   0.8955,   2.0000]], device='cuda:0')
# Individual Detection result: [227.9436798095703, 57.10231018066406, 415.89935302734375, 524.9329833984375, 0.8955063223838806, 2.0]
# Prediction bbox: 228 57 416 525, Conf: 0.896, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_76571017_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9101654846335697
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9939994.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9939994.txt
#
# Label File content (GT): [1.0, 0.5953125, 0.3890625, 0.1453125, 0.503125]
# GT Box (yolo to xyxy): [334, 88, 428, 410]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[329.0270,  88.1512, 435.4916, 411.9291,   0.7121,   2.0000]], device='cuda:0')
# Individual Detection result: [329.0269775390625, 88.15115356445312, 435.4915771484375, 411.92913818359375, 0.7120717763900757, 2.0]
# Prediction bbox: 329 88 435 412, Conf: 0.712, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9939994_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: brown IOU: 0.8813184253435826
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110753/mis_classification/116461_9939994_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_654793.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_654793.txt
#
# Label File content (GT): [3.0, 0.61015625, 0.50703125, 0.396875, 0.09765625]
# GT Box (yolo to xyxy): [264, 293, 518, 356]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[266.7971, 293.2723, 519.8270, 359.0176,   0.9323,   2.0000]], device='cuda:0')
# Individual Detection result: [266.797119140625, 293.27227783203125, 519.8270263671875, 359.01763916015625, 0.9323233366012573, 2.0]
# Prediction bbox: 267 293 520 359, Conf: 0.932, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_654793_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: green IOU: 0.9364007816663705
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110753/mis_classification/36514_654793_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36391_83669531.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36391_83669531.txt
#
# Label File content (GT): [4.0, 0.55234375, 0.51171875, 0.1921875, 0.36015625]
# GT Box (yolo to xyxy): [292, 212, 415, 443]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[295.3281, 198.5524, 412.5092, 435.9604,   0.8272,   4.0000]], device='cuda:0')
# Individual Detection result: [295.32806396484375, 198.5523681640625, 412.50921630859375, 435.96044921875, 0.8272415995597839, 4.0]
# Prediction bbox: 295 199 413 436, Conf: 0.827, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36391_83669531_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: knight IOU: 0.8826259725515077
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9938283.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9938283.txt
#
# Label File content (GT): [2.0, 0.34921875, 0.228125, 0.671875, 0.128125]
# GT Box (yolo to xyxy): [8, 105, 438, 187]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 knight_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[3.8553e-01, 1.0856e+02, 4.3984e+02, 1.8153e+02, 5.1156e-01, 4.0000e+00]], device='cuda:0')
# Individual Detection result: [0.385528564453125, 108.56439208984375, 439.8370056152344, 181.53292846679688, 0.5115598440170288, 4.0]
# Prediction bbox: 0 109 440 182, Conf: 0.512, Pred_label: knight
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_9938283_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: knight -> GT: crested IOU: 0.8721867185329258
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110753/mis_classification/36488_9938283_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_505559.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_505559.txt
#
# Label File content (GT): [3.0, 0.5125, 0.5375, 0.24296875, 0.15]
# GT Box (yolo to xyxy): [250, 296, 406, 392]
#
# --- Pipeline inference ---
#
# 0: 640x640 (no detections), 28.6ms
# Speed: 1.5ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([], device='cuda:0', size=(0, 6))
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_505559_annotated.jpg
# Annotated image saved to: inference/run_20251205_110753/missed_detections/36514_505559_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_85059967.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_85059967.txt
#
# Label File content (GT): [2.0, 0.58203125, 0.39375, 0.415625, 0.76875]
# GT Box (yolo to xyxy): [240, 6, 506, 498]
#
# --- Pipeline inference ---
# 0: 640x640 1 crested_anole, 28.5ms
# Speed: 1.4ms preprocess, 28.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[242.4068,   1.1142, 513.2827, 497.5369,   0.9505,   2.0000]], device='cuda:0')
# Individual Detection result: [242.40679931640625, 1.114227294921875, 513.28271484375, 497.53692626953125, 0.9504733681678772, 2.0]
# Prediction bbox: 242 1 513 498, Conf: 0.950, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_85059967_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.9573748258655129
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_92195440.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_92195440.txt
#
# Label File content (GT): [2.0, 0.52578125, 0.56328125, 0.64375, 0.87265625]
# GT Box (yolo to xyxy): [130, 81, 542, 639]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[129.6756,  79.8841, 338.6557, 495.1927,   0.6251,   2.0000]], device='cuda:0')
# Individual Detection result: [129.67556762695312, 79.88409423828125, 338.6556701660156, 495.19268798828125, 0.625051736831665, 2.0]
# Prediction bbox: 130 80 339 495, Conf: 0.625, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_92195440_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: crested
# Annotated image saved to: inference/run_20251205_110753/missed_detections/36488_92195440_annotated.jpg
# Annotated image saved to: inference/run_20251205_110753/false_positives/36488_92195440_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9940004.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9940004.txt
#
# Label File content (GT): [1.0, 0.528125, 0.73984375, 0.1125, 0.25390625]
# GT Box (yolo to xyxy): [302, 392, 374, 555]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[3.3918e+02, 1.2472e+02, 4.2617e+02, 4.3685e+02, 3.4645e-01, 3.0000e+00]], device='cuda:0')
# Individual Detection result: [339.18011474609375, 124.71978759765625, 426.16534423828125, 436.8465576171875, 0.34645092487335205, 3.0]
# Prediction bbox: 339 125 426 437, Conf: 0.346, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9940004_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# No best match found for Pred: green
# Annotated image saved to: inference/run_20251205_110753/missed_detections/116461_9940004_annotated.jpg
# Annotated image saved to: inference/run_20251205_110753/false_positives/116461_9940004_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_96743167.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_96743167.txt
#
# Label File content (GT): [0.0, 0.51652, 0.5229429429429429, 0.7635799999999999, 0.7361261261261262]
# GT Box (yolo to xyxy): [67, 52, 449, 297]
#
# --- Pipeline inference ---
#
# 0: 448x640 1 bark_anole, 23.6ms
# Speed: 1.8ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Raw Detection result: tensor([[ 65.8155,  32.6474, 455.4583, 308.3594,   0.9564,   0.0000]], device='cuda:0')
# Individual Detection result: [65.81549835205078, 32.64741897583008, 455.45831298828125, 308.35943603515625, 0.9563676714897156, 0.0]
# Prediction bbox: 66 33 455 308, Conf: 0.956, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36455_96743167_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: bark -> GT: bark IOU: 0.8748773077821921
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_9921619.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_9921619.txt
#
# Label File content (GT): [0.0, 0.53125, 0.4296875, 0.33984375, 0.45703125]
# GT Box (yolo to xyxy): [231, 129, 449, 421]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 bark_anole, 29.2ms
# Speed: 1.4ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[230.8698, 124.4832, 450.0500, 421.9545,   0.8503,   0.0000]], device='cuda:0')
# Individual Detection result: [230.8697967529297, 124.483154296875, 450.04998779296875, 421.9544677734375, 0.8503383994102478, 0.0]
# Prediction bbox: 231 124 450 422, Conf: 0.850, Pred_label: bark
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36455_9921619_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: bark -> GT: bark IOU: 0.9753914988814317
#
#
#
#  --- Analyzing Image ---
# ...
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_906339.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_906339.txt
#
# Label File content (GT): [3.0, 0.45078125, 0.48984375, 0.325, 0.5640625]
# GT Box (yolo to xyxy): [184, 133, 392, 494]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[189.4318, 132.3083, 392.8666, 493.7022,   0.8377,   3.0000]], device='cuda:0')
# Individual Detection result: [189.4317626953125, 132.30831909179688, 392.8665771484375, 493.7022399902344, 0.8377412557601929, 3.0]
# Prediction bbox: 189 132 393 494, Conf: 0.838, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_906339_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.968672755872206
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_857702.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_857702.txt
#
# Label File content (GT): [3.0, 0.44296875, 0.50703125, 0.80234375, 0.52265625]
# GT Box (yolo to xyxy): [27, 157, 540, 492]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[ 27.0791, 154.3768, 542.7372, 490.6953,   0.9580,   3.0000]], device='cuda:0')
# Individual Detection result: [27.0791015625, 154.37680053710938, 542.7371826171875, 490.6953430175781, 0.9579649567604065, 3.0]
# Prediction bbox: 27 154 543 491, Conf: 0.958, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_857702_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.9824374301195493
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_71716067.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_71716067.txt
#
# Label File content (GT): [0.0, 0.38626, 0.45047904191616767, 0.7662, 0.7213173652694611]
# GT Box (yolo to xyxy): [2, 30, 385, 271]
#
# --- Pipeline inference ---
#
# 0: 448x640 1 brown_anole, 23.6ms
# Speed: 1.8ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Raw Detection result: tensor([[  0.0000,  11.4711, 386.6260, 282.9077,   0.8726,   1.0000]], device='cuda:0')
# Individual Detection result: [0.0, 11.471080780029297, 386.62603759765625, 282.9077453613281, 0.8725584745407104, 1.0]
# Prediction bbox: 0 11 387 283, Conf: 0.873, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36455_71716067_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: bark IOU: 0.8768714850281197
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110753/mis_classification/36455_71716067_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36514_632856.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36514_632856.txt
#
# Label File content (GT): [3.0, 0.52265625, 0.3859375, 0.23984375, 0.128125]
# GT Box (yolo to xyxy): [258, 206, 411, 288]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 29.2ms
# Speed: 1.5ms preprocess, 29.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[253.2724, 165.8183, 411.3093, 288.0259,   0.7228,   3.0000]], device='cuda:0')
# Individual Detection result: [253.27235412597656, 165.81826782226562, 411.309326171875, 288.0259094238281, 0.7227670550346375, 3.0]
# Prediction bbox: 253 166 411 288, Conf: 0.723, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36514_632856_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: green IOU: 0.6508611745175348
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36455_9932138.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36455_9932138.txt
#
# Label File content (GT): [0.0, 0.37265625, 0.47578125, 0.11640625, 0.4703125]
# GT Box (yolo to xyxy): [201, 154, 276, 455]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[2.0356e+02, 1.5151e+02, 2.7975e+02, 5.7858e+02, 4.2039e-01, 2.0000e+00]], device='cuda:0')
# Individual Detection result: [203.5599365234375, 151.51271057128906, 279.75433349609375, 578.5791015625, 0.4203932285308838, 2.0]
# Prediction bbox: 204 152 280 579, Conf: 0.420, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36455_9932138_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: bark IOU: 0.6497376705141658
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110753/mis_classification/36455_9932138_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9879756.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9879756.txt
#
# Label File content (GT): [1.0, 0.49765625, 0.57109375, 0.17265625, 0.20625]
# GT Box (yolo to xyxy): [263, 300, 374, 432]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 brown_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[253.1562, 298.7862, 371.0384, 431.7397,   0.8977,   1.0000]], device='cuda:0')
# Individual Detection result: [253.1561737060547, 298.78619384765625, 371.03839111328125, 431.73974609375, 0.8976687788963318, 1.0]
# Prediction bbox: 253 299 371 432, Conf: 0.898, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9879756_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.8860161591050342
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9952804.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9952804.txt
#
# Label File content (GT): [1.0, 0.6515625, 0.47578125, 0.690625, 0.36171875]
# GT Box (yolo to xyxy): [196, 189, 638, 420]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 brown_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[195.0240, 186.0361, 640.0000, 458.0204,   0.6491,   1.0000]], device='cuda:0')
# Individual Detection result: [195.02398681640625, 186.03610229492188, 640.0, 458.0204162597656, 0.6491182446479797, 1.0]
# Prediction bbox: 195 186 639 458, Conf: 0.649, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9952804_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.8454391891891891
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_9935900.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_9935900.txt
#
# Label File content (GT): [2.0, 0.4953125, 0.55078125, 0.5578125, 0.22109375]
# GT Box (yolo to xyxy): [138, 282, 496, 423]
#
# --- Pipeline inference ---
# 0: 640x640 1 crested_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[ 99.4372, 283.1486, 496.0065, 423.3747,   0.8844,   2.0000]], device='cuda:0')
# Individual Detection result: [99.43724060058594, 283.14862060546875, 496.0064697265625, 423.37469482421875, 0.8843693137168884, 2.0]
# Prediction bbox: 99 283 496 423, Conf: 0.884, Pred_label: crested
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_9935900_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: crested -> GT: crested IOU: 0.8959919911330402
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9938205.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9938205.txt
#
# Label File content (GT): [1.0, 0.6171875, 0.315625, 0.62109375, 0.1796875]
# GT Box (yolo to xyxy): [196, 144, 594, 260]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 brown_anole, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[196.7592, 144.3617, 593.1387, 257.7115,   0.9135,   1.0000]], device='cuda:0')
# Individual Detection result: [196.75921630859375, 144.36166381835938, 593.138671875, 257.7115478515625, 0.9135361909866333, 1.0]
# Prediction bbox: 197 144 593 258, Conf: 0.914, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9938205_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: brown IOU: 0.9778201351585514
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/116461_9937794.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/116461_9937794.txt
#
# Label File content (GT): [1.0, 0.4875, 0.56015625, 0.42578125, 0.19765625]
# GT Box (yolo to xyxy): [176, 295, 448, 422]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 green_anole, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[173.4451, 300.8126, 448.0818, 420.5251,   0.7050,   3.0000]], device='cuda:0')
# Individual Detection result: [173.4451141357422, 300.8126220703125, 448.08184814453125, 420.52508544921875, 0.7049704194068909, 3.0]
# Prediction bbox: 173 301 448 421, Conf: 0.705, Pred_label: green
# Annotated image saved to: inference/run_20251205_110753/annotated_images/116461_9937794_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: green -> GT: brown IOU: 0.9351363740545496
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110753/mis_classification/116461_9937794_annotated.jpg
#
#
#
#  --- Analyzing Image ---
# Loaded image file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/images/36488_77845172.jpg
# Loaded label file: ../Dataset/yolo_training/florida_five_anole_10000_v4/test/labels/36488_77845172.txt
#
# Label File content (GT): [2.0, 0.59296875, 0.575, 0.79765625, 0.328125]
# GT Box (yolo to xyxy): [124, 263, 635, 473]
#
# --- Pipeline inference ---
#
# 0: 640x640 1 brown_anole, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Raw Detection result: tensor([[125.2851, 262.4339, 638.9731, 469.2704,   0.7184,   1.0000]], device='cuda:0')
# Individual Detection result: [125.28509521484375, 262.4339294433594, 638.9730834960938, 469.2703552246094, 0.7183976769447327, 1.0]
# Prediction bbox: 125 262 639 469, Conf: 0.718, Pred_label: brown
# Annotated image saved to: inference/run_20251205_110753/annotated_images/36488_77845172_annotated.jpg
#
# --- Matching each prediction to best ground truth bbox by IoU ---
# Best match found for Pred: brown -> GT: crested IOU: 0.966975922244312
# Mis-classification: Prediction label doesnt match with GT label
# Annotated image saved to: inference/run_20251205_110753/mis_classification/36488_77845172_annotated.jpg
#
# Saved evaluation results to inference/run_20251205_110753/eval_results.csv
#               precision    recall  f1-score   support
#
#         bark       0.78      0.71      0.74       202
#        brown       0.73      0.63      0.68       200
#      crested       0.69      0.74      0.71       204
#        green       0.76      0.72      0.74       203
#       knight       0.71      0.80      0.75       202
#   Background       0.00      0.00      0.00        66
#
#     accuracy                           0.68      1077
#    macro avg       0.61      0.60      0.60      1077
# weighted avg       0.69      0.68      0.68      1077
#
#
# --- Detection mAP Evaluation ---
#
# Evaluating AP at IoU = 0.50
#   AP for class 'bark' (id=0) at IoU=0.50: 0.6776
#   AP for class 'brown' (id=1) at IoU=0.50: 0.5403
#   AP for class 'crested' (id=2) at IoU=0.50: 0.6425
#   AP for class 'green' (id=3) at IoU=0.50: 0.6496
#   AP for class 'knight' (id=4) at IoU=0.50: 0.7340
#
# Evaluating AP at IoU = 0.55
#   AP for class 'bark' (id=0) at IoU=0.55: 0.6672
#   AP for class 'brown' (id=1) at IoU=0.55: 0.5065
#   AP for class 'crested' (id=2) at IoU=0.55: 0.6386
#   AP for class 'green' (id=3) at IoU=0.55: 0.6357
#   AP for class 'knight' (id=4) at IoU=0.55: 0.7107
#
# Evaluating AP at IoU = 0.60
#   AP for class 'bark' (id=0) at IoU=0.60: 0.6515
#   AP for class 'brown' (id=1) at IoU=0.60: 0.4886
#   AP for class 'crested' (id=2) at IoU=0.60: 0.6381
#   AP for class 'green' (id=3) at IoU=0.60: 0.6313
#   AP for class 'knight' (id=4) at IoU=0.60: 0.7053
#
# Evaluating AP at IoU = 0.65
#   AP for class 'bark' (id=0) at IoU=0.65: 0.6364
#   AP for class 'brown' (id=1) at IoU=0.65: 0.4747
#   AP for class 'crested' (id=2) at IoU=0.65: 0.6333
#   AP for class 'green' (id=3) at IoU=0.65: 0.6207
#   AP for class 'knight' (id=4) at IoU=0.65: 0.6760
#
# Evaluating AP at IoU = 0.70
#   AP for class 'bark' (id=0) at IoU=0.70: 0.6322
#   AP for class 'brown' (id=1) at IoU=0.70: 0.4342
#   AP for class 'crested' (id=2) at IoU=0.70: 0.6285
#   AP for class 'green' (id=3) at IoU=0.70: 0.5865
#   AP for class 'knight' (id=4) at IoU=0.70: 0.6169
#
# Evaluating AP at IoU = 0.75
#   AP for class 'bark' (id=0) at IoU=0.75: 0.6219
#   AP for class 'brown' (id=1) at IoU=0.75: 0.4098
#   AP for class 'crested' (id=2) at IoU=0.75: 0.6252
#   AP for class 'green' (id=3) at IoU=0.75: 0.5353
#   AP for class 'knight' (id=4) at IoU=0.75: 0.5978
#
# Evaluating AP at IoU = 0.80
#   AP for class 'bark' (id=0) at IoU=0.80: 0.5725
#   AP for class 'brown' (id=1) at IoU=0.80: 0.3616
#   AP for class 'crested' (id=2) at IoU=0.80: 0.6098
#   AP for class 'green' (id=3) at IoU=0.80: 0.4552
#   AP for class 'knight' (id=4) at IoU=0.80: 0.5433
#
# Evaluating AP at IoU = 0.85
#   AP for class 'bark' (id=0) at IoU=0.85: 0.4374
#   AP for class 'brown' (id=1) at IoU=0.85: 0.2984
#   AP for class 'crested' (id=2) at IoU=0.85: 0.5752
#   AP for class 'green' (id=3) at IoU=0.85: 0.3979
#   AP for class 'knight' (id=4) at IoU=0.85: 0.4998
#
# Evaluating AP at IoU = 0.90
#   AP for class 'bark' (id=0) at IoU=0.90: 0.3025
#   AP for class 'brown' (id=1) at IoU=0.90: 0.2360
#   AP for class 'crested' (id=2) at IoU=0.90: 0.4752
#   AP for class 'green' (id=3) at IoU=0.90: 0.3501
#   AP for class 'knight' (id=4) at IoU=0.90: 0.4222
#
# Evaluating AP at IoU = 0.95
#   AP for class 'bark' (id=0) at IoU=0.95: 0.1170
#   AP for class 'brown' (id=1) at IoU=0.95: 0.0895
#   AP for class 'crested' (id=2) at IoU=0.95: 0.2868
#   AP for class 'green' (id=3) at IoU=0.95: 0.1968
#   AP for class 'knight' (id=4) at IoU=0.95: 0.2326
#
# --- Summary mAP ---
# mAP@0.50      : 0.6488
# mAP@0.75      : 0.5580
# mAP@0.50:0.95 : 0.5141
#
# --- Plotting Precision-Recall Curves at IoU = 0.50 ---
# Saved Precision-Recall curves to: inference/run_20251205_110753/pr_curves_iou_50.png

# %% [markdown]
# ## Plot

# %%
from sklearn.metrics import accuracy_score
import os
import pandas as pd

RESULTS_PATH = "./inference/run_20251205_110753_yolov12x_class_eval/eval_results.csv"

if os.path.exists(RESULTS_PATH):
    df = pd.read_csv(RESULTS_PATH)
    y_true_all = df["y_true"].tolist()
    y_pred_all = df["y_pred"].tolist()

    # Compute top-1 accuracy
    top1_acc = accuracy_score(y_true_all, y_pred_all)
    print(f"Top-1 Accuracy: {top1_acc:.4f}")

    print(f"Loaded evaluation results from {RESULTS_PATH}")
else:
    print(f"Cannot find results path {RESULTS_PATH}")
# Out:
# Top-1 Accuracy: 0.6750
# Loaded evaluation results from ./inference/run_20251205_110753_yolov12x_class_eval/eval_results.csv

# %% [markdown]
# ### Visualize confusion matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
import os

NUM_CLASSES = 5
MISSED_CLASS_ID = 5
ALL_CLASSES = list(range(NUM_CLASSES)) + [MISSED_CLASS_ID]
CLASS_NAMES = ["Bark Anole", "Brown Anole", "Crested Anole", "Green Anole", "Knight Anole"] + ["Background"]

RESULTS_PATH = "./inference/run_20251205_110753_yolov12x_class_eval/eval_results.csv"

if os.path.exists(RESULTS_PATH):
    df = pd.read_csv(RESULTS_PATH)
    y_true_all = df["y_true"].tolist()
    y_pred_all = df["y_pred"].tolist()
    print(f"Loaded evaluation results from {RESULTS_PATH}")
else:
    print("Cannot find results path")

# Compute confusion matrix
cm = confusion_matrix(y_true_all, y_pred_all, labels=ALL_CLASSES)

# Plot heatmap
cm_df = pd.DataFrame(cm, index=CLASS_NAMES, columns=CLASS_NAMES)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt=".0f", cmap="Blues")
plt.title("Confusion Matrix (Including Missed Detections)")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.show()
# Out:
# Loaded evaluation results from ./inference/run_20251205_110753_yolov12x_class_eval/eval_results.csv

# %%
# Normalize by rows (true labels)
cm_normalized = cm.astype("float") / cm.sum(axis=1, keepdims=True)
cm_normalized = np.nan_to_num(cm_normalized)  # Avoid NaNs

# Plot heatmap
cm_df = pd.DataFrame(cm_normalized, index=CLASS_NAMES, columns=CLASS_NAMES)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt=".2f", cmap="Blues")
plt.title("Normalized Confusion Matrix (Including Missed Detections)")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.show()
